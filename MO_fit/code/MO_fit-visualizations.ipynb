# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import matplotlib.pyplot as plt
from plot_core_locations import plot_core_locations

# %%
fig, axes = plot_core_locations()

plt.savefig("/home/nld4814/perm/code/IMAU-FDM/MO_fit/figures/GR_core_locs.png", dpi=300, bbox_inches="tight")
