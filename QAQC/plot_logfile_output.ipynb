# %% [markdown]
# # Extracts values from the spinup and plots them, so we can identify any issues with convergence

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import matplotlib.pyplot as plt
import glob
import pandas as pd
from logfile_output import *

# %%
project_name="run_FGRN055-era055_1939-2023"
logfile_dir = f"/ec/res4/scratch/nld4814/{project_name}/logfiles/"
file_list = [f for f in glob.glob(logfile_dir)]

# %%
# plot the variables from each spinup file
point = np.random.randint(55000)
#point = "23298"
point_file = f"{logfile_dir}log_IMAU-FDM_cca_{point}.out"

spinup_dict = extract_spinup_data(point_file)
spinup_df = pd.DataFrame.from_dict(spinup_dict,orient="index")

plot_spinup_variables(spinup_dict, point)
